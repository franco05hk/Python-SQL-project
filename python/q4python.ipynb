# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data= pd.read_csv('q4.csv')

# %%
data.head
# Out:
# <bound method NDFrame.head of                 actor  total_film_rental_amount
# 0         Susan Davis                      3193
# 1      Gina Degeneres                      3129
# 2      Matthew Carrey                      2544
# 3         Mary Keitel                      2427
# 4      Scarlett Damon                      2404
# 5         Walter Torn                      2403
# 6         Henry Berry                      2392
# 7    Christian Akroyd                      2379
# 8  Angela Witherspoon                      2357
# 9   Cameron Zellweger                      2323>

# %%
sorted_df = df.sort_values(by='total_film_rental_amount', ascending=True)
print(sorted_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sorted_df = df.sort_values(by='total_film_rental_amount', ascending=True)
#       2 print(sorted_df)
#
# NameError: name 'df' is not defined

# %%
df = pd.DataFrame(data)

# Sort the DataFrame by 'total_film_rental_amount' in ascending order
sorted_df = df.sort_values(by='total_film_rental_amount', ascending=True)

print(sorted_df)
# Out:
#                 actor  total_film_rental_amount
# 9   Cameron Zellweger                      2323
# 8  Angela Witherspoon                      2357
# 7    Christian Akroyd                      2379
# 6         Henry Berry                      2392
# 5         Walter Torn                      2403
# 4      Scarlett Damon                      2404
# 3         Mary Keitel                      2427
# 2      Matthew Carrey                      2544
# 1      Gina Degeneres                      3129
# 0         Susan Davis                      3193

# %%
plt.figure(figsize=(10, 6))
plt.bar(sorted_df['actor'], sorted_df['total_film_rental_amount'])
plt.xlabel('Actor')
plt.ylabel('Total Film Rental Amount')
plt.title('Top 10 Actor')
plt.xticks(rotation=45)  
# Rotate actor labels for better readability

# Show the plot
plt.tight_layout()
plt.show()
